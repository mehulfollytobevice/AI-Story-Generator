# %% [markdown]
# # LSTM- Finetuning AWD-LSTM:
#
# Text generation is the task of producing new text from a given input prompt. An example of text generation using machine learning is `GitHub’s Copilot`, which can generate code. Apart from code generation, text generation models can:
#
# 1. Generate stories, for example, try passing “Once upon a time " as input to a GPT-2 model.
# 2. Generate poetry.
# 3. Complete a paragraph with missing sentences.
# 4. Summarize an article.
# 5. Answer questions given some context.
#
# And many more...
#
# In this notebook, we fine-tune AWD-LSTM for the task of story generation. We do so by training a causal language model.  A causal language model tries to predict the next token in a given input sequence. In this way, it builds an understanding of the data it is trained on.
#
# So, the model in this notebook is __finetuned__.
#
# __Agenda__:
#
# 1. Load the dataset from csv files
# 2. Tokenize and preprocess text
# 3. Create Batches
# 4. Fine-tune AWD-LSTM model
# 5. Evaluate trained model

# %% [markdown]
# ## Setup

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/My Drive/nlp
# Out:
# /content/gdrive/My Drive/nlp

# %%
# !ls
# Out:
# ai-story_gen  models			 story_gpt2
# data	      story_distilgpt2_finetune  story_gpt2_finetune

# %% [markdown]
# ## Parameters for notebook execution:
#
# It's better to store all the parameters we need for a successful execution in one place. This way it's easy to manage the parameters.

# %%
import os 

# current directory path
DIR_PATH=os.getcwd()

# %%
DIR_PATH
# Out:
# '/content/gdrive/My Drive/nlp'

# %%
# parameters

# SAMPLE
TRAIN_ROWS=50000
TEST_ROWS=5000

# PATH OF CSV FILES
TRAIN_PATH= DIR_PATH+"/data/train_df.csv"
VALID_PATH=DIR_PATH+"/data/valid_df.csv"
TEST_PATH= DIR_PATH+"/data/test_df.csv"

# DATA PROCESSING
CONTEXT_LEN=256

# HYPERPARAMETERS
TRAIN_BS= 64
TEST_BS= 64 
EPOCHS=5

# %% [markdown]
# ## Load the data

# %%
# import required libraries
from fastai.text.all import *
import pandas as pd

# %% [markdown]
# First, let's load the dataframes

# %%
# load the data
train_df = pd.read_csv(TRAIN_PATH)
test_df = pd.read_csv(TEST_PATH)
valid_df = pd.read_csv(VALID_PATH)

# %% [markdown]
# Let's drop the unecessary columns:
# - `Unnamed: 0`
# - `prompts`

# %%
train_df.drop(columns=['Unnamed: 0', 'prompts'], inplace=True)
test_df.drop(columns=['Unnamed: 0', 'prompts'], inplace=True)
valid_df.drop(columns=['Unnamed: 0', 'prompts'], inplace=True)

# %% [markdown]
# Selecting a subset of the data

# %%
train_df = train_df.sample(n=TRAIN_ROWS, random_state=42)
valid_df = valid_df.sample(n=TEST_ROWS, random_state=42)

# test_df = test_df[:600]

# %% [markdown]
# `Fastai` requires us to tell it whether the data is coming from the training set or the testing set. So, we need to create a `is_valid` column which tells us whether the row represents data from the training set or the validation set.

# %%
train_df['is_valid']=False
valid_df['is_valid']=True

# %%
valid_df.head(3)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       stories  \
# 4462  *Energy core online . Initializing start-up sequence . Optic sensors online . * <newline> <newline> Light . It always started with light . And then ... <newline> <newline> *Activating motor function . Radar online . Weapons system online . Downloading combat data . Prepare for war . * <newline> <newline> And then chaos . I stepped away from my constraints , eyes already searching the battlefield for enemy Spectres- mass produced , dumb AI whose only purpose was to destroy the plastic bodies of the enemy- gun at the ready . As the battle went on , one side would push toward the enemy , unti...
# 8719  Esar flicked his tail nervously as he prepared to walk onstage . After years in the field , working in the frigid cold of the lower continent and the scorching heat of deserts he was finally ready to report his findings to the world . Esar had spoken before massive crowds before , but this time was different , this time he would be changing his people 's entire view of the world . <newline> Then the clipboard wielding assistant motioned for him to go on , Esar gulped , then walked forward . <newline> `` Ladies and gentlemen ! '' He proclaimed to the audience . `` Today I am here to announc...
# 9380  Everyone sat silently in the darkened living room . The only sound that permeated through the darkness was the ticking of Mom 's old grandfather clock in the other room . Chris lost track of time after a few minutes . Or was it a few hours ? The clock dinged without warning . He counted eleven dings before it went back to it 's usual ticking . <newline> <newline> It is 11 P.M. and Dad will be getting home shortly . That 's the time he usually gets home , anyway , because that 's when he swings by the liquor stores right before they close . <newline> <newline> `` Thank you , everyone , for ...
#
#       is_valid
# 4462      True
# 8719      True
# 9380      True

# %% [markdown]
# Ok!!! Now, let's concatenate these two dataframes.

# %%
all_df = pd.concat([train_df, valid_df],ignore_index=True)

# %%
all_df.sample(n=4)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        stories  \
# 29015  `` Officer , I know what this looks like . '' <newline> <newline> The officer did know what it looked like . It looked like I was naked and had a raging erection . It also looked like I was sprawled on top of some unfortunate produce and may or may not have been defiling a melon . I can assure that while the melon was a sweetheart , it was not my type . <newline> <newline> <newline> `` You have thirty seconds to explain yourself son . Because I 'll be honest chasing you through a supermarket was not my idea of a good time . '' The kind officer said while attempting not to strangle me . <ne...
# 7847   Unlike in a separate timeline in which the Earth had been separated into 7 continents , we live on one super-continent . You may think that we would have learned to co-exist peacefully , but , of course , there were always border disputes . What was once part of the Russian Union became part of the Asia Coalition . What was once part of the America Amalgamation became part of the Great Empire of China . However , before the single continent of Gaea existed , there were two land-masses ; one with a rather large variety of dinosaurs , and one with mammals . And , the meteor that may have cau...
# 2248   The Last Stand ? <newline> <newline> <newline> By HiWhatsMyName <newline> <newline> <newline> <newline> The end was here . A battle that had raged on for days had come to a close . But somewhere in that bloody battlefield laid two men in different attire . James sat up , still in shock from the bullet that pierced through the side of his stomach . He felt the intense pain ravage his body and understood fully that this is where he would die . The Second World War seemed so close to being won . James believed he was going to see it through . But now he just sat back and watched the trees swa...
# 45839  I was walking down a street on an average Sunday . I 'd just `` Gone to church '' Then I `` Helped an old woman across the road . '' I decided that I needed to get Coffee . I walked into the Shop and got in line . It was too damn long . `` Excuse me '' I said , very politely , `` I 've got an incredibly important meeting to get to . '' The young woman stepped aside and let me pass . I repeated this until I was at the front of line , `` One small , non-fat , Latte please . '' The barista wrote down my order and I moved to the side . I learned across the counter , `` And could you make it fa...
#
#        is_valid
# 29015     False
# 7847      False
# 2248      False
# 45839     False

# %% [markdown]
# ## Creating DataBlock and dataloaders:
#
# In the last section, we loaded the data. Now, in this section, we will create the `DataBlock` and `Dataloaders` for the text data.

# %%
dsets= DataBlock(blocks=TextBlock.from_df('stories',min_freq=3,is_lm=True),
                    get_x=ColReader('text'),
                    splitter=ColSplitter())

# %%
dls = dsets.dataloaders(source=all_df,bs=TRAIN_BS,seq_len=CONTEXT_LEN)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# Let's see some examples from the dataloader.

# %%
dls.show_batch(max_n=5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>text_</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>xxbos xxmaj hi everyone , i ' m xxmaj cheryl . &lt; newline &gt; &lt; newline &gt; xxmaj thank you . i ' m pretty nervous up here , this is my first meeting for this support group . xxmaj any support group , really . &lt; newline &gt; &lt; newline &gt; xxmaj honestly , i do n't know if i belong here . xxmaj you guys … you ' ve got * real * problems , you know ? xxmaj you deserve the help , not me . i mean , i do n't grow porcupine quills that then shoot off unpredictably . xxmaj my voice does n't make people cry . i ' m not even * mildly * radioactive ! &lt; newline &gt; &lt; newline &gt; xxmaj thank you . i just wanted to say how much it means to me that you 're welcoming me to</td>
#       <td>xxmaj hi everyone , i ' m xxmaj cheryl . &lt; newline &gt; &lt; newline &gt; xxmaj thank you . i ' m pretty nervous up here , this is my first meeting for this support group . xxmaj any support group , really . &lt; newline &gt; &lt; newline &gt; xxmaj honestly , i do n't know if i belong here . xxmaj you guys … you ' ve got * real * problems , you know ? xxmaj you deserve the help , not me . i mean , i do n't grow porcupine quills that then shoot off unpredictably . xxmaj my voice does n't make people cry . i ' m not even * mildly * radioactive ! &lt; newline &gt; &lt; newline &gt; xxmaj thank you . i just wanted to say how much it means to me that you 're welcoming me to the</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>xxmaj anyway , it hits her in the face and she goes flying back down the hallway , so i decide to finish the job . i took the pillow and swung it wildly until she was completely out of my house . '' &lt; newline &gt; &lt; newline &gt; ` ` xxmaj what did your neighbors think about this ? '' &lt; newline &gt; &lt; newline &gt; ` ` xxmaj enough to make them move . '' &lt; newline &gt; &lt; newline &gt; ` ` xxmaj well , maybe we could give you a super hero name ? '' &lt; newline &gt; &lt; newline &gt; ` ` xxmaj like what ? '' &lt; newline &gt; &lt; newline &gt; ` ` xxmaj xxunk . '' xxmaj david said with a grin , raising a fresh mug to me . &lt; newline &gt; &lt; newline &gt; ` ` xxmaj cheers ,</td>
#       <td>anyway , it hits her in the face and she goes flying back down the hallway , so i decide to finish the job . i took the pillow and swung it wildly until she was completely out of my house . '' &lt; newline &gt; &lt; newline &gt; ` ` xxmaj what did your neighbors think about this ? '' &lt; newline &gt; &lt; newline &gt; ` ` xxmaj enough to make them move . '' &lt; newline &gt; &lt; newline &gt; ` ` xxmaj well , maybe we could give you a super hero name ? '' &lt; newline &gt; &lt; newline &gt; ` ` xxmaj like what ? '' &lt; newline &gt; &lt; newline &gt; ` ` xxmaj xxunk . '' xxmaj david said with a grin , raising a fresh mug to me . &lt; newline &gt; &lt; newline &gt; ` ` xxmaj cheers , you</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>. i wince as the metal pulls against my hair . &lt; newline &gt; &lt; newline &gt; “ xxmaj what if he thinks i ’ m some harlot ? ” &lt; newline &gt; &lt; newline &gt; “ xxmaj he won ’ t think that . ” &lt; newline &gt; &lt; newline &gt; “ xxmaj what if that ’ s the only reason he ’ s interested in me ? ” &lt; newline &gt; xxmaj sarah doesn ’ t answer even though i know she heard me . &lt; newline &gt; &lt; newline &gt; xxmaj even if i wanted to hide it , i couldn ’ t . xxmaj even now , in the mirror , the results of xxup xxunk stare back at me . xxmaj my skin , which used to be greasy and covered in acne and scars , is now clear , my complexion smooth . xxmaj</td>
#       <td>i wince as the metal pulls against my hair . &lt; newline &gt; &lt; newline &gt; “ xxmaj what if he thinks i ’ m some harlot ? ” &lt; newline &gt; &lt; newline &gt; “ xxmaj he won ’ t think that . ” &lt; newline &gt; &lt; newline &gt; “ xxmaj what if that ’ s the only reason he ’ s interested in me ? ” &lt; newline &gt; xxmaj sarah doesn ’ t answer even though i know she heard me . &lt; newline &gt; &lt; newline &gt; xxmaj even if i wanted to hide it , i couldn ’ t . xxmaj even now , in the mirror , the results of xxup xxunk stare back at me . xxmaj my skin , which used to be greasy and covered in acne and scars , is now clear , my complexion smooth . xxmaj my</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>newline &gt; xxmaj he pulled it out . &lt; newline &gt; &lt; newline &gt; xxmaj the sword came out so easily , as if it were stuck in butter . xxmaj the boy felt the light weight in his hand , and smiled . xxmaj he had always thought swords were heavy , but this felt like nothing in his hand . &lt; newline &gt; &lt; newline &gt; xxmaj it was beautiful . &lt; newline &gt; &lt; newline &gt; ` ` xxmaj what ? '' xxmaj henry heard the voice of his sixteen year old sister behind him . ` ` xxmaj where did you get that ? '' &lt; newline &gt; &lt; newline &gt; xxmaj henry 's smile was fixed on . xxmaj he turned around , towards his sister and held it up . ` ` xxmaj look at it , it 's beautiful . '' &lt; newline</td>
#       <td>&gt; xxmaj he pulled it out . &lt; newline &gt; &lt; newline &gt; xxmaj the sword came out so easily , as if it were stuck in butter . xxmaj the boy felt the light weight in his hand , and smiled . xxmaj he had always thought swords were heavy , but this felt like nothing in his hand . &lt; newline &gt; &lt; newline &gt; xxmaj it was beautiful . &lt; newline &gt; &lt; newline &gt; ` ` xxmaj what ? '' xxmaj henry heard the voice of his sixteen year old sister behind him . ` ` xxmaj where did you get that ? '' &lt; newline &gt; &lt; newline &gt; xxmaj henry 's smile was fixed on . xxmaj he turned around , towards his sister and held it up . ` ` xxmaj look at it , it 's beautiful . '' &lt; newline &gt;</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>i laughed and agreed ` ` xxmaj where are you from ? '' &lt; newline &gt; &lt; newline &gt; xxmaj she moved a piece of hair away from her face and tucked it behind he ear , ` ` no where around here , xxmaj tod '' . xxmaj she looked down at her phone , i watched her eyebrows furrow . &lt; newline &gt; &lt; newline &gt; ` ` xxmaj what s the matter ? '' &lt; newline &gt; &lt; newline &gt; ` ` xxmaj nothing , xxmaj it 's just maybe .. you could show me your apartment ? '' ` ` do you live around here ? '' &lt; newline &gt; &lt; newline &gt; i was taken aback , i had n't even gotten her phone number yet , and honestly what is a beautiful woman like her doing coming home with a guy like me .</td>
#       <td>laughed and agreed ` ` xxmaj where are you from ? '' &lt; newline &gt; &lt; newline &gt; xxmaj she moved a piece of hair away from her face and tucked it behind he ear , ` ` no where around here , xxmaj tod '' . xxmaj she looked down at her phone , i watched her eyebrows furrow . &lt; newline &gt; &lt; newline &gt; ` ` xxmaj what s the matter ? '' &lt; newline &gt; &lt; newline &gt; ` ` xxmaj nothing , xxmaj it 's just maybe .. you could show me your apartment ? '' ` ` do you live around here ? '' &lt; newline &gt; &lt; newline &gt; i was taken aback , i had n't even gotten her phone number yet , and honestly what is a beautiful woman like her doing coming home with a guy like me . however</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Training the Model:
# After the data processing is done, we need to train the model.

# %%
learn = language_model_learner(dls, AWD_LSTM, drop_mult=0.3, 
    metrics=[accuracy, Perplexity()]
    ).to_fp16()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='105070592' class='' max='105067061' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [105070592/105067061 00:03&lt;00:00]
#     </div>

# %%
# find the optimal learning rate
learn.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=0.005248074419796467)

# %%
# train the language model
learn.fit_one_cycle(2, 1e-2)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.583390</td>
#       <td>3.507299</td>
#       <td>0.357845</td>
#       <td>33.358036</td>
#       <td>19:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.503302</td>
#       <td>3.457469</td>
#       <td>0.362553</td>
#       <td>31.736534</td>
#       <td>19:25</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.unfreeze()
learn.fit_one_cycle(1, 2e-3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.247372</td>
#       <td>3.247491</td>
#       <td>0.390382</td>
#       <td>25.725723</td>
#       <td>19:29</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save("story_awd_lstm_finetune")
# Out:
# Path('models/story_awd_lstm_finetune.pth')

# %% [markdown]
# ## Story Generation:

# %%
learn.load("story_awd_lstm_finetune")

# %% [markdown]
# Generate a story to see how the model is performing.

# %%
TEXT = "i like pizza"
N_WORDS = 100
N_SENTENCES = 1
preds = [learn.predict(TEXT, N_WORDS, temperature=0.75) 
         for _ in range(N_SENTENCES)]
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
print('\n'.join(preds))
# Out:
# i like pizza . There i am . In the shadows , i can see you . The Great Black . Black , the Red , Dark , Blue , Red , Red , Red King , Red , Blue , Red , Blue , Red . Red . Red . Blue . Grey . < newline > < newline > Red is the Green . Black is the Green line . i hear it from my

# %% [markdown]
# ### Finally let's evaluate our language model:
#
# The evaluation of a text generation task can be subjective and depend on the specific goals of the task. However, there are several common methods that can be used to evaluate the quality of the generated text.
#
# 1. __Human evaluation:__ One of the most reliable methods for evaluating text generation is through human evaluation. This involves having human evaluators read the generated text and rate its quality based on various metrics such as coherence, fluency, and relevance to the prompt or topic. This method provides a subjective evaluation of the text and can give insights into how well the generated text matches human writing.
#
# 2. __Automated metrics:__ Automated metrics can be used to evaluate text generation based on various quantitative measures. Examples of automated metrics include perplexity, BLEU score, and ROUGE score. These metrics compare the generated text to a reference text or corpus, and provide a measure of the similarity between the two texts.
#
# 3. __Domain-specific metrics:__ For text generation tasks that are focused on a specific domain, such as medical or legal writing, domain-specific metrics can be used to evaluate the quality of the generated text. These metrics are designed to measure the accuracy and completeness of the generated text within the specific domain.
#
# 4. __User testing:__ In some cases, user testing can be used to evaluate the quality of the generated text. This involves having users interact with the generated text and providing feedback on its quality, usefulness, and relevance to the task or topic.

# %% [markdown]
# __Perplexity__

# %%
valid_perplexity = learn.validate()[2]
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
valid_perplexity
# Out:
# 25.725723266601562
